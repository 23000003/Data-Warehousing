# %%
import pandas as pd

# %%
df_dimLoc = pd.read_csv('./Dim_Location.csv')
df_dimLoc.head()
# Out:
#    Location_ID  STREET_NO STREET_DIRECTION    STREET_NAME   LATITUDE  \
# 0            0       2101                S    ASHLAND AVE  41.854120
# 1            1       1320                E        47TH ST  41.809781
# 2            2       3210                W     FOSTER AVE  41.975853
# 3            3       7458                S  LAFAYETTE AVE  41.758246
# 4            4       1100                W    DIVISION ST  41.903640
#
#    LONGITUDE  LOCATION_UNIQUE_ID
# 0 -87.665902               79253
# 1 -87.594213               52633
# 2 -87.709134              114645
# 3 -87.626522              207656
# 4 -87.655547               44455

# %%
df_dimCC = pd.read_csv('./Dim_Crash_Condition.csv')
df_dimCC.head()
# Out:
#    Crash_Condition_ID WEATHER_CONDITION LIGHTING_CONDITION  \
# 0                   0             CLEAR           DAYLIGHT
# 1                   1           UNKNOWN            UNKNOWN
# 2                   2             CLEAR           DAYLIGHT
# 3                   3             CLEAR           DAYLIGHT
# 4                   4           UNKNOWN            UNKNOWN
#
#   ROADWAY_SURFACE_COND  CRASH_CONDITION_UNIQUE_ID
# 0                  DRY                         15
# 1              UNKNOWN                        206
# 2                  DRY                         15
# 3                  DRY                         15
# 4              UNKNOWN                        206

# %%
df_Incident = pd.read_csv('./Dim_Incident.csv')
df_Incident.head()
# Out:
#    Incident_ID                 REPORT_TYPE INTERSECTION_RELATED_I  \
# 0            0                    ON SCENE                unknown
# 1            1  NOT ON SCENE (DESK REPORT)                unknown
# 2            2                    ON SCENE                unknown
# 3            3                    ON SCENE                      Y
# 4            4  NOT ON SCENE (DESK REPORT)                unknown
#
#   HIT_AND_RUN_I  NUM_UNITS  Incident_Unique_ID
# 0             Y          4                 112
# 1             Y          2                  39
# 2       unknown          3                 126
# 3       unknown          2                  88
# 4             Y          2                  39

# %%
df_CrashType = pd.read_csv('./Dim_Crash_Type.csv')
df_CrashType.head()
# Out:
#    Crash_Type_ID          FIRST_CRASH_TYPE  \
# 0              0      PARKED MOTOR VEHICLE
# 1              1                     ANGLE
# 2              2                  REAR END
# 3              3                     ANGLE
# 4              4  SIDESWIPE SAME DIRECTION
#
#                   PRIM_CONTRIBUTORY_CAUSE  \
# 0  FAILING TO REDUCE SPEED TO AVOID CRASH
# 1                     UNABLE TO DETERMINE
# 2                     UNABLE TO DETERMINE
# 3                     UNABLE TO DETERMINE
# 4                     UNABLE TO DETERMINE
#
#                               SEC_CONTRIBUTORY_CAUSE  CRASH_TYPE_UNIQUE_ID
# 0  OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELE...                  2124
# 1                                     NOT APPLICABLE                   488
# 2                                UNABLE TO DETERMINE                  3768
# 3                                UNABLE TO DETERMINE                   494
# ...

# %%
df_CrashType = df_CrashType.drop_duplicates(subset='CRASH_TYPE_UNIQUE_ID')
df_CrashType.head()

print(f"Length of the dataset: {len(df_CrashType)}")
# Out:
# Length of the dataset: 5820
